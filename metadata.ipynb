# %%
import pandas as pd

# %%
meta_2 = pd.read_csv('/Volumes/Samsung SSD 990 EVO Plus 4TB/HPA_single_cells_data/Master_scKaggle.csv')

# %%
meta_2
# Out:
#                                            file  \
# 0                            10005_921_B9_1.png
# 1                            10005_921_B9_2.png
# 2                            10005_923_B9_1.png
# 3                            10005_923_B9_2.png
# 4                            10005_931_B9_1.png
# ...                                         ...
# 93808  dd0989c4-bbca-11e8-b2bc-ac1f6b6435d0.png
# 93809  dd1f7fb8-bbca-11e8-b2bc-ac1f6b6435d0.png
# 93810  dd5cb36a-bbca-11e8-b2bc-ac1f6b6435d0.png
# 93811  df573730-bbca-11e8-b2bc-ac1f6b6435d0.png
# 93812  dea19dc6-bbca-11e8-b2bc-ac1f6b6435d0.png
#
#                                          ID org_label  \
# 0                            10005_921_B9_1        25
# 1                            10005_921_B9_2        25
# 2                            10005_923_B9_1        25
# 3                            10005_923_B9_2        25
# 4                            10005_931_B9_1        25
# ...                                     ...       ...
# ...
